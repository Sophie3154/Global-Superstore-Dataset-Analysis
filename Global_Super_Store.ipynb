# %%
import pandas as pd

import kagglehub
path = kagglehub.dataset_download("apoorvaappz/global-super-store-dataset")

import os
print(os.listdir(path))

import glob
files = glob.glob(path + "/*.csv")
# Out:
# ['Global_Superstore2.xlsx', 'Global_Superstore2.csv']

# %%
df = pd.read_csv("/kaggle/input/global-super-store-dataset/Global_Superstore2.csv", encoding='latin1')
df.head(30)
# Out:
#     Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0    32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1    26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2    25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3    13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4    47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# 5    22732    IN-2013-42360  28-06-2013  01-07-2013    Second Class
# 6    30570    IN-2011-81826  07-11-2011  09-11-2011     First Class
# 7    31192    IN-2012-86369  14-04-2012  18-04-2012  Standard Class
# 8    40155   CA-2014-135909  14-10-2014  21-10-2014  Standard Class
# 9    40936   CA-2012-116638  28-01-2012  31-01-2012    Second Class
# 10   34577   CA-2011-102988  05-04-2011  09-04-2011    Second Class
# 11   28879    ID-2012-28402  19-04-2012  22-04-2012     First Class
# 12   45794     SA-2011-1830  27-12-2011  29-12-2011    Second Class
# ...

# %%
list(df.columns)
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'City',
#  'State',
#  'Country',
#  'Postal Code',
#  'Market',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Shipping Cost',
#  'Order Priority']

# %%
#Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (51290, 24)

# %%
#Check for missing values
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df['Postal Code'].head()
# Out:
# 0    10024.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# Name: Postal Code, dtype: float64

# %%
#Delete Postal Code columns
df = df.drop(columns=['Postal Code'])

# %%
#Check the dataframe columns
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
#Convert datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df['Order Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#Format / type errors
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
#Check input errors
cols = ['Ship Mode', 'Segment', 'City','State','Country', 'Market', 'Region','Category', 'Sub-Category',
       'Product Name','Order Priority']

for col in cols:
  print(col)
  print(df[col].unique())
# Out:
# Ship Mode
# ['Same Day' 'Second Class' 'First Class' 'Standard Class']
# Segment
# ['Consumer' 'Corporate' 'Home Office']
# City
# ['New York City' 'Wollongong' 'Brisbane' ... 'Abilene' 'Felahiye'
#  'Victoria Falls']
# State
# ['New York' 'New South Wales' 'Queensland' ... 'Manicaland' 'Kabarole'
#  'Matabeleland North']
# Country
# ['United States' 'Australia' 'Germany' 'Senegal' 'New Zealand'
#  'Afghanistan' 'Saudi Arabia' 'Brazil' 'China' 'France' 'Italy' 'Tanzania'
#  'Poland' 'United Kingdom' 'Mexico' 'El Salvador' 'Taiwan' 'India'
#  'Dominican Republic' 'Democratic Republic of the Congo' 'Indonesia'
#  'Uruguay' 'Iran' 'Mozambique' 'Bangladesh' 'Spain' 'Ukraine' 'Nicaragua'
#  'Morocco' 'Canada' 'Philippines' 'Austria' 'Colombia' 'Netherlands'
#  'Malaysia' 'Ecuador' 'Thailand' 'Somalia' 'Guatemala' 'Belarus'
#  'Cambodia' 'South Africa' 'Japan' 'Russia' 'Egypt' 'Azerbaijan'
#  'Lithuania' 'Argentina' 'Lesotho' 'Vietnam' 'Cuba' 'Romania' 'Turkey'
# ...

# %%
#Check for inconsistent values
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date         Sales      Quantity  \
# count                          51290  51290.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528    246.490581      3.476545
# min              2011-01-03 00:00:00      0.444000      1.000000
# 25%              2012-06-23 00:00:00     30.758625      2.000000
# 50%              2013-07-12 00:00:00     85.053000      3.000000
# 75%              2014-05-26 00:00:00    251.053200      5.000000
# ...

# %%
#Analysis

# %%
#Customer Analysis

# %%
#Profile the customers based on their frequency of purchase - calculate frequency of purchase for each customer

# %%
#Customer purchase count
purchase_count = df['Customer ID'].value_counts()
purchase_count
# Out:
# Customer ID
# PO-18850    97
# BE-11335    94
# JG-15805    90
# SW-20755    89
# MY-18295    85
#             ..
# BG-1035      1
# MG-7650      1
# ME-8010      1
# MG-7890      1
# ZC-11910     1
# Name: count, Length: 1590, dtype: int64

# %%
purchase_count.describe()
# Out:
# count    1590.000000
# mean       32.257862
# std        21.910515
# min         1.000000
# 25%        12.000000
# 50%        28.000000
# 75%        52.000000
# max        97.000000
# Name: count, dtype: float64

# %%
#Bucketing purchase frequencies
def get_bucket(counts):
  if counts <= 12:
    return "Low"
  elif counts <= 52:
    return "Medium"
  else:
    return "High"

# %%
#Mapping get_bucket to purchase_count
buckets = purchase_count.map(get_bucket)
buckets
# Out:
# Customer ID
# PO-18850    High
# BE-11335    High
# JG-15805    High
# SW-20755    High
# MY-18295    High
#             ...
# BG-1035      Low
# MG-7650      Low
# ME-8010      Low
# MG-7890      Low
# ZC-11910     Low
# Name: count, Length: 1590, dtype: object

# %%
#Add buckets to the df
df['Purchase Frequency'] = df['Customer ID'].map(buckets)

# %%
buckets.value_counts()
# Out:
# count
# Medium    783
# Low       431
# High      376
# Name: count, dtype: int64

# %%
#Do the high frequent customers contribute more revenue?

# %%
#Customers generating the most revenue
sales = df.groupby('Purchase Frequency')['Sales'].sum()
sales
# Out:
# Purchase Frequency
# High      6.268688e+06
# Low       5.834987e+05
# Medium    5.790315e+06
# Name: Sales, dtype: float64

# %%
#Are they also profitable - what is the profit margin across the buckets

# %%
#Customers generating the most profit
profit_margin = df.groupby('Purchase Frequency')['Profit'].sum()
profit_margin
# Out:
# Purchase Frequency
# High      755084.55418
# Low        60769.51900
# Medium    651603.21810
# Name: Profit, dtype: float64

# %%
#Profit margin percentage
margin_percentage = (profit_margin / sales)*100
margin_percentage
# Out:
# Purchase Frequency
# High      12.045336
# Low       10.414680
# Medium    11.253329
# dtype: float64

# %%
#Which customer segment is most profitable in each year?

# %%
#Extract year
df['year'] = df['Order Date'].dt.year
df
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
#Customer segment profit by year
segment_profit = df.groupby(['year', 'Segment'])['Profit'].sum().reset_index()
segment_profit
# Out:
#     year      Segment        Profit
# 0   2011     Consumer  117337.49406
# 1   2011    Corporate   84746.93574
# 2   2011  Home Office   46856.38174
# 3   2012     Consumer  165799.19094
# 4   2012    Corporate   90556.69992
# 5   2012  Home Office   51059.38824
# 6   2013     Consumer  208427.73398
# 7   2013    Corporate  125707.93908
# 8   2013  Home Office   72799.55712
# 9   2014     Consumer  257675.36308
# 10  2014    Corporate  140196.75392
# 11  2014  Home Office  106293.85346

# %%
#Visualization
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(data = segment_profit, x= 'year', y= 'Profit', hue= 'Segment')
plt.title("Customer Segment Profit by Year")
plt.xlabel('Year')
plt.show()

# %%
#How the customers are distributed across the countries?

# %%
#Group clients by countries
country_client = df.groupby('Country')['Customer ID'].nunique().reset_index()
country_client.columns = ['Country', 'Customer ID']

# %%
#Visualization
import plotly.express as px

fig = px.choropleth(
    country_client,
    locations='Country',
    locationmode='country names',
    color='Customer ID',
    hover_name='Country',
    color_continuous_scale='Blues',
    title='Customer Distribution across the Countries'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Top 10 countries
country_client_sorted = df.groupby('Country')['Customer ID'].nunique().sort_values(ascending=False)
top_10 = country_client_sorted.head(10)
top_10
# Out:
# Country
# United States     793
# France            679
# Mexico            670
# Australia         660
# Germany           582
# China             549
# United Kingdom    529
# India             494
# Brazil            472
# Indonesia         469
# Name: Customer ID, dtype: int64

# %%
#Visualization
sns.barplot(x= top_10.index, y= top_10.values)
plt.ylabel("Number of Customers")
plt.title('Top 10 Customer Distribution across the Countries')
plt.xticks(rotation = 45)
plt.show()

# %%
#Product Analysis

# %%
#Which country has top sales?

# %%
top_sales = df.groupby('Country')['Sales'].sum().sort_values(ascending=False)
top_sales
# Out:
# Country
# United States        2.297201e+06
# Australia            9.252359e+05
# France               8.589311e+05
# China                7.005620e+05
# Germany              6.288400e+05
#                          ...
# Tajikistan           2.427840e+02
# Macedonia            2.096400e+02
# Eritrea              1.877400e+02
# Armenia              1.567500e+02
# Equatorial Guinea    1.505100e+02
# Name: Sales, Length: 147, dtype: float64

# %%
#Which are the top 5 profit-making product types on a yearly basis

# %%
#Product profit by year
profit_product = df.groupby(['year', 'Product Name', 'Sub-Category'])['Profit'].sum()
profit_product
# Out:
# year  Product Name                                                                                         Sub-Category
# 2011  #10 White Business Envelopes,4 1/8 x 9 1/2                                                           Envelopes       73.6490
#       #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                              Envelopes       21.2382
#       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes                                                         Envelopes       11.2308
#       1.7 Cubic Foot Compact "Cube" Office Refrigerators                                                   Appliances      85.3456
#       1/4 Fold Party Design Invitations & White Envelopes, 24 8-1/2" X 11" Cards, 25 Env./Pack             Paper            1.9845
#                                                                                                                             ...
# ...

# %%
#Create a new dataframe
profit_product_df = profit_product.reset_index()
profit_product_df
# Out:
#        year                                       Product Name Sub-Category  \
# 0      2011         #10 White Business Envelopes,4 1/8 x 9 1/2    Envelopes
# 1      2011            #10- 4 1/8" x 9 1/2" Recycled Envelopes    Envelopes
# 2      2011       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes    Envelopes
# 3      2011  1.7 Cubic Foot Compact "Cube" Office Refrigera...   Appliances
# 4      2011  1/4 Fold Party Design Invitations & White Enve...        Paper
# ...     ...                                                ...          ...
# 12798  2014  iKross Bluetooth Portable Keyboard + Cell Phon...       Phones
# 12799  2014                         iOttie HLCRIO102 Car Mount       Phones
# 12800  2014                                iOttie XL Car Mount       Phones
# 12801  2014  invisibleSHIELD by ZAGG Smudge-Free Screen Pro...       Phones
# 12802  2014                 netTALK DUO VoIP Telephone Service       Phones
#
#         Profit
# 0      73.6490
# 1      21.2382
# ...

# %%
#Sort the dataframe
def top_5_profit_product(group):
  #Sort by descending profit
  group_sorted = group.sort_values(by='Profit', ascending= False)
  #Keep top 5 profit product
  top_5 = group_sorted.head(5)
  return top_5

# %%
#Top 5 products by year
top_5_products = profit_product_df.groupby('year').apply(top_5_profit_product)
top_5_products_by_year = top_5_products.reset_index(drop=True)
top_5_products_by_year
# Out:
# /tmp/ipykernel_3488/2691384993.py:2: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#     year                                       Product Name Sub-Category  \
# 0   2011               Ibico EPK-21 Electric Binding System      Binders
# 1   2011                  Cisco Smart Phone, with Caller ID       Phones
# 2   2011                        Nokia Smart Phone, Cordless       Phones
# 3   2011                          Samsung Smart Phone, VoIP       Phones
# 4   2011                       Nokia Smart Phone, Full Size       Phones
# 5   2012  Fellowes PB500 Electric Punch Plastic Comb Bin...      Binders
# 6   2012                  Zebra ZM400 Thermal Label Printer     Machines
# ...

# %%
#Partition the table by year
top_5_products_by_year['year'].unique()

df_2011 = top_5_products_by_year[top_5_products_by_year['year'] == 2011]
df_2012 = top_5_products_by_year[top_5_products_by_year['year'] == 2012]
df_2013 = top_5_products_by_year[top_5_products_by_year['year'] == 2013]
df_2014 = top_5_products_by_year[top_5_products_by_year['year'] == 2014]

# %%
#Top 5 products in 2011
df_2011
# Out:
#    year                          Product Name Sub-Category     Profit
# 0  2011  Ibico EPK-21 Electric Binding System      Binders  4630.4755
# 1  2011     Cisco Smart Phone, with Caller ID       Phones  4066.8580
# 2  2011           Nokia Smart Phone, Cordless       Phones  3880.1850
# 3  2011             Samsung Smart Phone, VoIP       Phones  3414.3100
# 4  2011          Nokia Smart Phone, Full Size       Phones  3332.4630

# %%
#Top 5 products in 2012
df_2012
# Out:
#    year                                       Product Name Sub-Category  \
# 5  2012  Fellowes PB500 Electric Punch Plastic Comb Bin...      Binders
# 6  2012                  Zebra ZM400 Thermal Label Printer     Machines
# 7  2012                     Samsung Smart Phone, Full Size       Phones
# 8  2012                       Nokia Smart Phone, Full Size       Phones
# 9  2012                Samsung Smart Phone, with Caller ID       Phones
#
#       Profit
# 5  7498.8410
# 6  3343.5360
# 7  2978.8680
# 8  2877.1665
# 9  2781.8375

# %%
#Top 5 products in 2013
df_2013
# Out:
#     year                                       Product Name Sub-Category  \
# 10  2013              Canon imageCLASS 2200 Advanced Copier      Copiers
# 11  2013                    Motorola Smart Phone, Full Size       Phones
# 12  2013  Harbour Creations Executive Leather Armchair, ...       Chairs
# 13  2013                       Cisco Smart Phone, Full Size       Phones
# 14  2013                                 Belkin Router, USB  Accessories
#
#        Profit
# 10  9519.9728
# 11  7529.4882
# 12  6424.5296
# 13  6305.4030
# 14  4554.8420

# %%
#Top 5 products in 2014
df_2014
# Out:
#     year                           Product Name Sub-Category      Profit
# 15  2014  Canon imageCLASS 2200 Advanced Copier      Copiers  15679.9552
# 16  2014           Cisco Smart Phone, Full Size       Phones   7262.3480
# 17  2014        Motorola Smart Phone, Full Size       Phones   6307.5570
# 18  2014                      Hoover Stove, Red   Appliances   5123.2340
# 19  2014   Sauder Classic Bookcase, Traditional    Bookcases   4937.9690

# %%
#How is the product price varying with sales? Is there any increase in sales with the decrease in price at a day level

# %%
#Average price per day
df['Price'] = df['Sales'] / df['Quantity']
mean_price = df.groupby(['Product Name', 'Order Date'])['Price'].mean()
mean_price
# Out:
# Product Name                                          Order Date
# "While you Were Out" Message Book, One Form per Page  2014-09-04     2.968
#                                                       2014-10-31     3.710
#                                                       2014-11-14     2.968
# #10 Gummed Flap White Envelopes, 100/Box              2012-11-03     3.304
#                                                       2013-01-15     4.130
#                                                                      ...
# netTALK DUO VoIP Telephone Service                    2011-12-05    41.992
#                                                       2012-06-20    41.992
#                                                       2012-09-25    52.490
#                                                       2013-01-09    41.992
#                                                       2014-07-04    41.992
# Name: Price, Length: 50410, dtype: float64

# %%
#Quantity sold per day
quantity_sold = df.groupby(['Product Name', 'Order Date'])['Quantity'].sum()
quantity_sold
# Out:
# Product Name                                          Order Date
# "While you Were Out" Message Book, One Form per Page  2014-09-04    3
#                                                       2014-10-31    2
#                                                       2014-11-14    3
# #10 Gummed Flap White Envelopes, 100/Box              2012-11-03    2
#                                                       2013-01-15    4
#                                                                    ..
# netTALK DUO VoIP Telephone Service                    2011-12-05    4
#                                                       2012-06-20    3
#                                                       2012-09-25    2
#                                                       2013-01-09    9
#                                                       2014-07-04    4
# Name: Quantity, Length: 50410, dtype: int64

# %%
daily_data = df.groupby(['Product Name', 'Order Date']).agg({'Price': 'mean', 'Quantity': 'sum'}).reset_index()
daily_data
# Out:
#                                             Product Name Order Date   Price  \
# 0      "While you Were Out" Message Book, One Form pe... 2014-09-04   2.968
# 1      "While you Were Out" Message Book, One Form pe... 2014-10-31   3.710
# 2      "While you Were Out" Message Book, One Form pe... 2014-11-14   2.968
# 3               #10 Gummed Flap White Envelopes, 100/Box 2012-11-03   3.304
# 4               #10 Gummed Flap White Envelopes, 100/Box 2013-01-15   4.130
# ...                                                  ...        ...     ...
# 50405                 netTALK DUO VoIP Telephone Service 2011-12-05  41.992
# 50406                 netTALK DUO VoIP Telephone Service 2012-06-20  41.992
# 50407                 netTALK DUO VoIP Telephone Service 2012-09-25  52.490
# 50408                 netTALK DUO VoIP Telephone Service 2013-01-09  41.992
# 50409                 netTALK DUO VoIP Telephone Service 2014-07-04  41.992
#
#        Quantity
# 0             3
# 1             2
# ...

# %%
#Visualization
sns.scatterplot(data= daily_data, x='Price', y='Quantity', alpha= 0.4)
plt.xlabel("Average Price")
plt.ylabel("Quantity Sold")
plt.title("Sales vs Price per Day")
plt.show()

# %%
#Trend
sns.lmplot(data=daily_data, x='Price', y='Quantity', height=6, aspect=1.5)
plt.xlabel("Average Price")
plt.ylabel("Quantity Sold")
plt.title("Sales vs Price per Day with Trend")
plt.show()

# %%
#What is the average delivery time across the counties?

# %%
#Delivery time
df['Delivery_time_day'] = df['Ship Date'] - df['Order Date']
df
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
df['Delivery_time_days'] = df['Delivery_time_day'] / pd.Timedelta(days=1)

# %%
#Average delivery time by region
avg_time_market = df.groupby('Market')['Delivery_time_days'].mean()
avg_time_market
# Out:
# Market
# APAC      3.969097
# Africa    3.910399
# Canada    3.677083
# EMEA      3.933386
# EU        4.008300
# LATAM     3.996794
# US        3.958875
# Name: Delivery_time_days, dtype: float64

# %%
avg_time = avg_time_market.reset_index()
avg_time
# Out:
#    Market  Delivery_time_days
# 0    APAC            3.969097
# 1  Africa            3.910399
# 2  Canada            3.677083
# 3    EMEA            3.933386
# 4      EU            4.008300
# 5   LATAM            3.996794
# 6      US            3.958875

# %%
#Barplot
plt.figure(figsize=(10,5))
sns.barplot(data=avg_time, x='Market', y='Delivery_time_days')
plt.xlabel("Market")
plt.ylabel("Avg Delivery Time")
plt.title("Average Delivery Time across the Market")
plt.xticks(rotation=45)
plt.show()
